# %% [markdown]
# ## Benchmarking
#
# 1. Transformer
# 2. PatchTST
# 3. Autoformer
# 4. DLinear
# 5. iTransformer
# 6. TimeXer
# 7. TimeXer (fine-tuned)

# %%
# !bash scripts/SCINet.sh
# Out:
# True
# Args in experiment:
# Basic Config
#   Task Name:          long_term_forecast  Is Training:        1
#   Model ID:           ECL_168_24          Model:              SCINet
#
# Data Loader
#   Data:               custom              Root Path:          ./data/
#   Data Path:          causal_data.csv     Features:           MS
#   Target:             electricity_price   Freq:               h
#   Checkpoints:        ./checkpoints/
#   Predictor(s):       solar_forecast,wind_forecast,total_load
#
# Forecasting Task
#   Seq Len:            168                 Label Len:          48
#   Pred Len:           24                  Seasonal Patterns:  Monthly
#   Inverse:            0
#
# Model Parameters
#   Top k:              5                   Num Kernels:        6
#   Enc In:             4                   Dec In:             4
#   C Out:              1                   d model:            512
#   n heads:            8                   e layers:           3
# ...

# %%
# !bash scripts/PatchTST.sh
# Out:
# True
# Args in experiment:
# Basic Config
#   Task Name:          long_term_forecast  Is Training:        1
#   Model ID:           ECL_168_24          Model:              PatchTST
#
# Data Loader
#   Data:               custom              Root Path:          ./data/
#   Data Path:          causal_data.csv     Features:           MS
#   Target:             electricity_price   Freq:               h
#   Checkpoints:        ./checkpoints/
#   Predictor(s):       solar_forecast,wind_forecast,total_load
#
# Forecasting Task
#   Seq Len:            168                 Label Len:          48
#   Pred Len:           24                  Seasonal Patterns:  Monthly
#   Inverse:            0
#
# Model Parameters
#   Top k:              5                   Num Kernels:        6
#   Enc In:             4                   Dec In:             4
#   C Out:              1                   d model:            512
#   n heads:            8                   e layers:           3
# ...

# %%
# !bash scripts/Autoformer.sh
# Out:
# True
# Args in experiment:
# Basic Config
#   Task Name:          long_term_forecast  Is Training:        1
#   Model ID:           ECL_168_24          Model:              Autoformer
#
# Data Loader
#   Data:               custom              Root Path:          ./data/
#   Data Path:          causal_data.csv     Features:           MS
#   Target:             electricity_price   Freq:               h
#   Checkpoints:        ./checkpoints/
#   Predictor(s):       solar_forecast,wind_forecast,total_load
#
# Forecasting Task
#   Seq Len:            168                 Label Len:          48
#   Pred Len:           24                  Seasonal Patterns:  Monthly
#   Inverse:            0
#
# Model Parameters
#   Top k:              5                   Num Kernels:        6
#   Enc In:             4                   Dec In:             4
#   C Out:              1                   d model:            512
#   n heads:            8                   e layers:           3
# ...

# %%
# !bash scripts/DLinear.sh
# Out:
# True
# Args in experiment:
# Basic Config
#   Task Name:          long_term_forecast  Is Training:        1
#   Model ID:           ECL_168_24          Model:              DLinear
#
# Data Loader
#   Data:               custom              Root Path:          ./data/
#   Data Path:          causal_data.csv     Features:           MS
#   Target:             electricity_price   Freq:               h
#   Checkpoints:        ./checkpoints/
#   Predictor(s):       solar_forecast,wind_forecast,total_load
#
# Forecasting Task
#   Seq Len:            168                 Label Len:          48
#   Pred Len:           24                  Seasonal Patterns:  Monthly
#   Inverse:            0
#
# Model Parameters
#   Top k:              5                   Num Kernels:        6
#   Enc In:             4                   Dec In:             4
#   C Out:              1                   d model:            512
#   n heads:            8                   e layers:           3
# ...

# %%
# !bash scripts/Transformer.sh
# Out:
# True
# Args in experiment:
# Basic Config
#   Task Name:          long_term_forecast  Is Training:        1
#   Model ID:           ECL_168_24          Model:              Transformer
#
# Data Loader
#   Data:               custom              Root Path:          ./data/
#   Data Path:          causal_data.csv     Features:           MS
#   Target:             electricity_price   Freq:               h
#   Checkpoints:        ./checkpoints/
#   Predictor(s):       solar_forecast,wind_forecast,total_load
#
# Forecasting Task
#   Seq Len:            168                 Label Len:          48
#   Pred Len:           24                  Seasonal Patterns:  Monthly
#   Inverse:            0
#
# Model Parameters
#   Top k:              5                   Num Kernels:        6
#   Enc In:             4                   Dec In:             4
#   C Out:              1                   d model:            512
#   n heads:            8                   e layers:           3
# ...

# %%
# !bash scripts/iTransformer.sh
# Out:
# True
# Args in experiment:
# Basic Config
#   Task Name:          long_term_forecast  Is Training:        1
#   Model ID:           ECL_168_24          Model:              iTransformer
#
# Data Loader
#   Data:               custom              Root Path:          ./data/
#   Data Path:          causal_data.csv     Features:           MS
#   Target:             electricity_price   Freq:               h
#   Checkpoints:        ./checkpoints/
#   Predictor(s):       solar_forecast,wind_forecast,total_load
#
# Forecasting Task
#   Seq Len:            168                 Label Len:          48
#   Pred Len:           24                  Seasonal Patterns:  Monthly
#   Inverse:            0
#
# Model Parameters
#   Top k:              5                   Num Kernels:        6
#   Enc In:             4                   Dec In:             4
#   C Out:              1                   d model:            512
#   n heads:            8                   e layers:           3
# ...

# %%
# !bash ./scripts/TimeXer.sh
# Out:
# True
# Args in experiment:
# Basic Config
#   Task Name:          long_term_forecast  Is Training:        1
#   Model ID:           EPF_168_24          Model:              TimeXer
#
# Data Loader
#   Data:               custom              Root Path:          ./data/
#   Data Path:          causal_data.csv     Features:           MS
#   Target:             electricity_price   Freq:               h
#   Checkpoints:        ./checkpoints/
#   Predictor(s):       solar_forecast,wind_forecast,total_load
#
# Forecasting Task
#   Seq Len:            168                 Label Len:          48
#   Pred Len:           24                  Seasonal Patterns:  Monthly
#   Inverse:            0
#
# Model Parameters
#   Top k:              5                   Num Kernels:        6
#   Enc In:             4                   Dec In:             4
#   C Out:              1                   d model:            256
#   n heads:            8                   e layers:           2
# ...

# %%
# !bash scripts/TimeXer.sh --dropout 0.2 --e_layers 2 --d_model 256 --patch_len 24
# Out:
# True
# Args in experiment:
# Basic Config
#   Task Name:          long_term_forecast  Is Training:        1
#   Model ID:           EPF_168_24          Model:              TimeXer
#
# Data Loader
#   Data:               custom              Root Path:          ./data/
#   Data Path:          causal_data.csv     Features:           MS
#   Target:             electricity_price   Freq:               h
#   Checkpoints:        ./checkpoints/
#   Predictor(s):       solar_forecast,wind_forecast,total_load
#
# Forecasting Task
#   Seq Len:            168                 Label Len:          48
#   Pred Len:           24                  Seasonal Patterns:  Monthly
#   Inverse:            0
#
# Model Parameters
#   Top k:              5                   Num Kernels:        6
#   Enc In:             4                   Dec In:             4
#   C Out:              1                   d model:            256
#   n heads:            8                   e layers:           2
# ...

# %%
# !bash scripts/TimeXer.sh --features S --learning_rate 5e-4 --dropout 0.2 --e_layers 2 --d_model 256 --patch_len 24 --enc_in 1 --dec_in 1 --c_out 1
# Out:
# True
# Args in experiment:
# Basic Config
#   Task Name:          long_term_forecast  Is Training:        1
#   Model ID:           EPF_168_24          Model:              TimeXer
#
# Data Loader
#   Data:               custom              Root Path:          ./data/
#   Data Path:          causal_data.csv     Features:           S
#   Target:             electricity_price   Freq:               h
#   Checkpoints:        ./checkpoints/
#   Predictor(s):       solar_forecast,wind_forecast,total_load
#
# Forecasting Task
#   Seq Len:            168                 Label Len:          48
#   Pred Len:           24                  Seasonal Patterns:  Monthly
#   Inverse:            0
#
# Model Parameters
#   Top k:              5                   Num Kernels:        6
#   Enc In:             1                   Dec In:             1
#   C Out:              1                   d model:            256
#   n heads:            8                   e layers:           2
# ...
